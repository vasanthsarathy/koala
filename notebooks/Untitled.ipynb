# %%
from PyPDF2 import PdfReader

reader = PdfReader("../data/cd.pdf")

cd = ""
for page in reader.pages:
    cd += page.extract_text() + "\n\n"

# %%
print(cd)
# Out:
# Conceptual Dependency Theory
# (CD), Schank 1975
# •focuses on concepts instead of syntax.
# •focuses on understanding instead of structure.
# •assumes inference is fundamental to understanding.
# •introduced idea of a canonical meaning representation.
# •different words and structures represent the same concept.
# •language-independent meaning representation.Canonical Meaning Representations
# John gave Mary a book.
# John gave a book to Mary.
# Mary was given a book by John.
# Mary took a book from John.
# Mary received a book from John.
# Tenets of Conceptual Dependency Theory
# (ICU, Schank & Riesbeck)
# •The representation of events is separate from the words used to encode them.
# •The task of the understander is to represent the events underlying sentences,
# rather than the sentences themselves.
# •Event representations are governed by a set of rules that involve fitting inputs
# into a predefined representation scheme.
# ...
